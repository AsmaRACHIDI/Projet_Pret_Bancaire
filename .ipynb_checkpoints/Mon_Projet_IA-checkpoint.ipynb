# %% [markdown]
# **Objectif du projet**: Prédire si un client est éligible à un prêt.
#
# **Les étapes du projet :**
#
# **EDA (Analyse Exploratoire des Données) :**
# - prise en main du jeu de données, nettoyage
# - analyse de corrélation des variables
# - définition des variables pertinentes
#
# => output : dataframe propre avec les variables pertinentes pour la prédiction du prix du bien
#
# **Base de données SQL :**
# - prendre bdd nettoyée (nans, duplicates, outliers)
# - garder les colonnes qui peuvent être utiles meme si c'est pas utile pour nos predictions (dans mon cas garder id pour sql)
# - garder les données catégorielle (on les numérisera plus tard)
#
# **Développer un programme d'intelligence artificielle :**
# - choix et entrainement de modèles de prédiction
# - évaluation et comparaison de ces modèles
# - enregister le modèle le plus performant (pickle..)
#
# => output: retenir le modèle plus performant.
#
# **Développement API (Flask) :**
# - définir une application flask
# - charger le modèle de prédiction retenu
#
# => output: tester le modèle à partir d'une page web.

# %% [markdown]
# ## EDA
#
# Prise en main du  jeu de données:
# - collecte, nettoyage de données
# - vérifications/transformations de types (int,float,datetime,string ..) + définition de nouvelles variables(date? ..)
# - vérification des données: valeurs uniques(distinctes)/ nulles/ non renseignées / outliers ? (boxplot)...

# %% [markdown]
# ### Importation des librairies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import GridSearchCV

# %matplotlib inline 

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importation des données

# %%
#loading the dataset
train = pd.read_csv(r'C:\Users\Asma\Documents\ExoSimplon\Sem15_Grand_Projet\Data\train_u6lujuX_CVtuZ9i.csv')
test = pd.read_csv(r'C:\Users\Asma\Documents\ExoSimplon\Sem15_Grand_Projet\Data\test_Y3wMUE5_7gLdaTN.csv')

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# 3             NaN         Urban
# 4             1.0         Urban

# %% [markdown]
# => Pas de colonne target = 'Loan_Status' pour le test set

# %%
print('Train shape : ', train.shape, '\nTest  shape : ', test.shape)
# Out:
# Train shape :  (614, 13)
# Test  shape :  (367, 12)

# %% [markdown]
# - Concaténer les deux dataframes train et test

# %%
#df = pd.concat([train, test])

# %%
#df.shape

# %%
# use .describe() to get more information on the dataset. 
train.describe().T
# Out:
#                    count         mean          std    min     25%     50%  \
# ApplicantIncome    614.0  5403.459283  6109.041673  150.0  2877.5  3812.5
# CoapplicantIncome  614.0  1621.245798  2926.248369    0.0     0.0  1188.5
# LoanAmount         592.0   146.412162    85.587325    9.0   100.0   128.0
# Loan_Amount_Term   600.0   342.000000    65.120410   12.0   360.0   360.0
# Credit_History     564.0     0.842199     0.364878    0.0     1.0     1.0
#
#                        75%      max
# ApplicantIncome    5795.00  81000.0
# CoapplicantIncome  2297.25  41667.0
# LoanAmount          168.00    700.0
# Loan_Amount_Term    360.00    480.0
# Credit_History        1.00      1.0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# ### Vérification des doubons

# %%
train.duplicated().sum()
# Out:
# 0

# %%
#train[train.duplicated()]

# %%
#train.drop_duplicates(inplace=True)

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %% [markdown]
# ### Vérification et Gestion des données manquantes (NAN)

# %%
train.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# - Remplacement de 'Gender'

# %%
train['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
train['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
train.dropna(subset=['Gender'],inplace=True)
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
train['Gender'].isna().sum()
# Out:
# 0

# %%
train.reset_index(drop=True) #drop=true permet de supprimer l'ancien index et garder que le réindexage
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 596  LP002978  Female      No          0      Graduate            No
# 597  LP002979    Male     Yes         3+      Graduate            No
# 598  LP002983    Male     Yes          1      Graduate            No
# 599  LP002984    Male     Yes          2      Graduate            No
# 600  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 596             2900                0.0        71.0             360.0
# 597             4106                0.0        40.0             180.0
# 598             8072              240.0       253.0             360.0
# 599             7583                0.0       187.0             360.0
# 600             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 596             1.0         Rural           Y
# 597             1.0         Rural           Y
# 598             1.0         Urban           Y
# 599             1.0         Urban           Y
# 600             0.0     Semiurban           N
#
# [601 rows x 13 columns]

# %%
train['Gender'].isna().sum()
# Out:
# 0

# %%
train.isna().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       49
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# - Remplacement de 'Married'

# %%
train['Married'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
train['Married'] = train['Married'].fillna('No')

# %%
train['Married'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
train.isna().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       49
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# - Remplacement de 'Dependents'

# %%
train['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
train.Dependents = train.Dependents.fillna('0')

rpl = {'0':'0', '1':'1', '2':'2', '3+':'3'}

train.Dependents = train.Dependents.replace(rpl).astype(int)

# %%
train.Dependents.unique()
# Out:
# array([0, 1, 2, 3])

# %%
train.isna().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       49
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# - Remplacement de 'Self_Employed'

# %%
train['Self_Employed'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
train['Self_Employed'].value_counts()
# Out:
# No     491
# Yes     78
# Name: Self_Employed, dtype: int64

# %%
train['Self_Employed'] = train['Self_Employed'].fillna('No')

# %%
train['Self_Employed'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
train['Self_Employed'].value_counts()
# Out:
# No     523
# Yes     78
# Name: Self_Employed, dtype: int64

# %%
train.isna().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       49
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# - Remplacement de 'Credit_History'

# %%
train['Credit_History'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
train['Credit_History'].value_counts()
# Out:
# 1.0    466
# 0.0     86
# Name: Credit_History, dtype: int64

# %%
train['Credit_History'].isna().sum()
# Out:
# 49

# %%
train.dropna(subset=['Credit_History'],inplace=True)

# %%
train.reset_index(drop=True) #drop=true permet de supprimer l'ancien index et garder que le réindexage
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002    Male      No           0      Graduate            No
# 1    LP001003    Male     Yes           1      Graduate            No
# 2    LP001005    Male     Yes           0      Graduate           Yes
# 3    LP001006    Male     Yes           0  Not Graduate            No
# 4    LP001008    Male      No           0      Graduate            No
# ..        ...     ...     ...         ...           ...           ...
# 547  LP002978  Female      No           0      Graduate            No
# 548  LP002979    Male     Yes           3      Graduate            No
# 549  LP002983    Male     Yes           1      Graduate            No
# 550  LP002984    Male     Yes           2      Graduate            No
# 551  LP002990  Female      No           0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 547             2900                0.0        71.0             360.0
# 548             4106                0.0        40.0             180.0
# 549             8072              240.0       253.0             360.0
# 550             7583                0.0       187.0             360.0
# 551             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 547             1.0         Rural           Y
# 548             1.0         Rural           Y
# 549             1.0         Urban           Y
# 550             1.0         Urban           Y
# 551             0.0     Semiurban           N
#
# [552 rows x 13 columns]

# %%
train['Credit_History'].isna().sum()
# Out:
# 0

# %% [markdown]
# - Remplacement de 'LoanAmount'

# %%
train['LoanAmount'].unique()
# Out:
# array([ nan, 128.,  66., 120., 141., 267.,  95., 158., 168., 349.,  70.,
#        109., 200., 114.,  17., 125.,  76., 133., 115., 104., 315., 116.,
#        191., 122., 110.,  35.,  74., 106., 320., 100., 144., 184.,  80.,
#         47., 134.,  96.,  88.,  44., 112., 286.,  97., 135., 180.,  99.,
#        165., 258., 126., 312., 136., 172.,  81., 187., 113., 176., 111.,
#        167.,  50., 210., 175., 131., 188.,  25., 137., 151., 160., 225.,
#        216.,  94., 139., 152., 118., 185., 154., 259., 194., 102., 290.,
#         84., 242., 129.,  30., 244., 600., 255.,  98., 275., 121.,  75.,
#        182.,  63.,  87., 101., 495.,  73., 260., 108.,  48., 164., 170.,
#         83.,  90., 166., 124.,  55.,  59., 127., 214., 240., 130.,  72.,
#         60., 138.,  42., 280., 140., 155., 123., 201., 279., 192., 304.,
#        150., 207., 436.,  78.,  54.,  89., 143.,  93., 105., 132., 480.,
#         56., 300., 376.,  67., 117.,  71., 490., 173.,  46., 228., 308.,
#        236., 570., 380., 296., 156., 103.,  45.,  65.,  53., 360.,  62.,
#        218., 178., 239., 405., 148., 149., 153., 162., 230.,  86., 234.,
#        246., 500., 119., 107., 209., 208., 243.,  40., 250., 311., 400.,
#        161., 324., 157., 145., 181.,  26., 211.,   9., 186., 205.,  36.,
#        146., 142., 496., 253.])

# %%
#train['LoanAmount'].fillna(train['LoanAmount'].mode()[0], inplace=True)

# %%
train.dropna(subset=['LoanAmount'],inplace=True)

# %%
train.reset_index(drop=True) #drop=true permet de supprimer l'ancien index et garder que le réindexage
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0    LP001003    Male     Yes           1      Graduate            No
# 1    LP001005    Male     Yes           0      Graduate           Yes
# 2    LP001006    Male     Yes           0  Not Graduate            No
# 3    LP001008    Male      No           0      Graduate            No
# 4    LP001011    Male     Yes           2      Graduate           Yes
# ..        ...     ...     ...         ...           ...           ...
# 526  LP002978  Female      No           0      Graduate            No
# 527  LP002979    Male     Yes           3      Graduate            No
# 528  LP002983    Male     Yes           1      Graduate            No
# 529  LP002984    Male     Yes           2      Graduate            No
# 530  LP002990  Female      No           0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               4583             1508.0       128.0             360.0
# 1               3000                0.0        66.0             360.0
# 2               2583             2358.0       120.0             360.0
# 3               6000                0.0       141.0             360.0
# 4               5417             4196.0       267.0             360.0
# ..               ...                ...         ...               ...
# 526             2900                0.0        71.0             360.0
# 527             4106                0.0        40.0             180.0
# 528             8072              240.0       253.0             360.0
# 529             7583                0.0       187.0             360.0
# 530             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Rural           N
# 1               1.0         Urban           Y
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 526             1.0         Rural           Y
# 527             1.0         Rural           Y
# 528             1.0         Urban           Y
# 529             1.0         Urban           Y
# 530             0.0     Semiurban           N
#
# [531 rows x 13 columns]

# %%
train['LoanAmount'].isna().sum()
# Out:
# 0

# %% [markdown]
# - Remplacement de 'Loan_Amount_Term'

# %%
train['Loan_Amount_Term'].unique()
# Out:
# array([360., 120.,  nan, 180.,  60., 300., 480., 240.,  36.,  84.])

# %%
#train['Loan_Amount_Term'].fillna(train['Loan_Amount_Term'].mode()[0], inplace=True)

# %%
train.dropna(subset=['Loan_Amount_Term'],inplace=True)

# %%
train.reset_index(drop=True) #drop=true permet de supprimer l'ancien index et garder que le réindexage
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0    LP001003    Male     Yes           1      Graduate            No
# 1    LP001005    Male     Yes           0      Graduate           Yes
# 2    LP001006    Male     Yes           0  Not Graduate            No
# 3    LP001008    Male      No           0      Graduate            No
# 4    LP001011    Male     Yes           2      Graduate           Yes
# ..        ...     ...     ...         ...           ...           ...
# 512  LP002978  Female      No           0      Graduate            No
# 513  LP002979    Male     Yes           3      Graduate            No
# 514  LP002983    Male     Yes           1      Graduate            No
# 515  LP002984    Male     Yes           2      Graduate            No
# 516  LP002990  Female      No           0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               4583             1508.0       128.0             360.0
# 1               3000                0.0        66.0             360.0
# 2               2583             2358.0       120.0             360.0
# 3               6000                0.0       141.0             360.0
# 4               5417             4196.0       267.0             360.0
# ..               ...                ...         ...               ...
# 512             2900                0.0        71.0             360.0
# 513             4106                0.0        40.0             180.0
# 514             8072              240.0       253.0             360.0
# 515             7583                0.0       187.0             360.0
# 516             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Rural           N
# 1               1.0         Urban           Y
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 512             1.0         Rural           Y
# 513             1.0         Rural           Y
# 514             1.0         Urban           Y
# 515             1.0         Urban           Y
# 516             0.0     Semiurban           N
#
# [517 rows x 13 columns]

# %%
train['Loan_Amount_Term'].isna().sum()
# Out:
# 0

# %% [markdown]
# - Revérification des NaNs

# %%
train.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
print('Train shape :', train.shape)
# Out:
# Train shape : (517, 13)

# %% [markdown]
# ### Changer les types des données

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 517 entries, 1 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            517 non-null    object
#  1   Gender             517 non-null    object
#  2   Married            517 non-null    object
#  3   Dependents         517 non-null    int32
#  4   Education          517 non-null    object
#  5   Self_Employed      517 non-null    object
#  6   ApplicantIncome    517 non-null    int64
#  7   CoapplicantIncome  517 non-null    float64
#  8   LoanAmount         517 non-null    float64
#  9   Loan_Amount_Term   517 non-null    float64
#  10  Credit_History     517 non-null    float64
#  11  Property_Area      517 non-null    object
#  12  Loan_Status        517 non-null    object
# dtypes: float64(4), int32(1), int64(1), object(7)
# memory usage: 54.5+ KB

# %%
train['Credit_History'] = train['Credit_History'].astype(int)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 517 entries, 1 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            517 non-null    object
#  1   Gender             517 non-null    object
#  2   Married            517 non-null    object
#  3   Dependents         517 non-null    int32
#  4   Education          517 non-null    object
#  5   Self_Employed      517 non-null    object
#  6   ApplicantIncome    517 non-null    int64
#  7   CoapplicantIncome  517 non-null    float64
#  8   LoanAmount         517 non-null    float64
#  9   Loan_Amount_Term   517 non-null    float64
#  10  Credit_History     517 non-null    int32
#  11  Property_Area      517 non-null    object
#  12  Loan_Status        517 non-null    object
# dtypes: float64(3), int32(2), int64(1), object(7)
# memory usage: 52.5+ KB

# %%
train.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 1  LP001003   Male     Yes           1      Graduate            No
# 2  LP001005   Male     Yes           0      Graduate           Yes
# 3  LP001006   Male     Yes           0  Not Graduate            No
# 4  LP001008   Male      No           0      Graduate            No
# 5  LP001011   Male     Yes           2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 1               1         Rural           N
# 2               1         Urban           Y
# 3               1         Urban           Y
# 4               1         Urban           Y
# 5               1         Urban           Y

# %%
train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# ### Créer une copie de mon df

# %%
new_train = train.copy()

# %% [markdown]
# # BDD SQL

# %%
from sqlalchemy import create_engine
mdp='Maroc.93600'

# %% [markdown]
# ### Séparation des 3 tables du MCD (Modèle Conceptuel de Données)

# %%
df_Loan = train[['Loan_ID', 'LoanAmount', 'Loan_Amount_Term', 'Loan_Status']]
df_Loan.head()
# Out:
#     Loan_ID  LoanAmount  Loan_Amount_Term Loan_Status
# 1  LP001003       128.0             360.0           N
# 2  LP001005        66.0             360.0           Y
# 3  LP001006       120.0             360.0           Y
# 4  LP001008       141.0             360.0           Y
# 5  LP001011       267.0             360.0           Y

# %%
df_Client = train[['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 
                   'Credit_History', 'ApplicantIncome', 'CoapplicantIncome']]
df_Client.head()
# Out:
#   Gender Married  Dependents     Education Self_Employed  Credit_History  \
# 1   Male     Yes           1      Graduate            No               1
# 2   Male     Yes           0      Graduate           Yes               1
# 3   Male     Yes           0  Not Graduate            No               1
# 4   Male      No           0      Graduate            No               1
# 5   Male     Yes           2      Graduate           Yes               1
#
#    ApplicantIncome  CoapplicantIncome
# 1             4583             1508.0
# 2             3000                0.0
# 3             2583             2358.0
# 4             6000                0.0
# 5             5417             4196.0

# %%
df_Property_Area = train[['Property_Area']]
df_Property_Area.head()
# Out:
#   Property_Area
# 1         Rural
# 2         Urban
# 3         Urban
# 4         Urban
# 5         Urban

# %% [markdown]
# ### Création des 3 tables en SQL sur MySQL

# %% [raw]
# sql_create = """
# CREATE TABLE IF NOT EXISTS Produits (
#    ref int(6) NOT NULL,
#    nom varchar(100) DEFAULT NULL,
#    stock int(4) DEFAULT NULL,
#    prix float(5,2) DEFAULT NULL,
#    PRIMARY KEY(ref),
#    CHECK (stock>=0) ); """
# try:
#    conn = mysql.connector.connect(host="192.168.125.2",
#                                   user="georges", password="what-else?",
#                                   database="magasin")
#    cursor = conn.cursor()
#    cursor.execute(sql_create)

# %% [markdown]
# ### Méthode 1: insertion des données Sans Pandas

# %% [markdown]
# - Attention!!! Avant de lancer la connection avec le serveur, il faut d'abord aller sur mysql workbench
# - Cliquer en haut a gauche sur +sql puis dans la fenetre a droite, creer la bdd
#
# - CREATE database Loan_bdd

# %%
conn = create_engine("mysql+mysqlconnector://root:"+mdp+"@localhost:3306/Loan_bdd", echo=True)
conn.connect()
# Out:
# 2022-10-09 00:07:45,697 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2022-10-09 00:07:45,697 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-10-09 00:07:45,700 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2022-10-09 00:07:45,701 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-10-09 00:07:45,704 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2022-10-09 00:07:45,705 INFO sqlalchemy.engine.Engine [raw sql] {}

# %%
#df_Property_Area = train[['Property_Area']]
#Property_Area_ID INTEGER PRIMARY KEY AUTOINCREMENT,

# création de la table "Property_Area" 
sql_query = ''' DROP TABLE IF EXISTS Property_Area'''
conn.execute(sql_query)
sql_query = '''CREATE TABLE Property_Area(
               Property_Area_ID  INT NOT NULL AUTO_INCREMENT, 
               Property_Area  VARCHAR(20),
               PRIMARY KEY (Property_Area_ID)
               )'''

conn.execute(sql_query)

#insertion des données"
cols = ",".join([str(i) for i in df_Property_Area.columns.tolist()]) # la liste des colonnes
print(cols)
df_Property_Area.head()
for i,row in df_Property_Area.iterrows():
    sql_query = "INSERT INTO Property_Area (" +cols + ") VALUES (" + "%s,"*(len(row)-1) + "%s)"
    #reference = (554871, "Confiture de fraise 250g", 10, 4.8)
    #conn.execute("""INSERT INTO Produits (ref, nom, stock, prix) VALUES(%s, %s, %s, %s)""", reference)
    print(sql_query)
    conn.execute(sql_query, tuple(row))
# Out:
# 2022-10-09 00:07:47,326 INFO sqlalchemy.engine.Engine  DROP TABLE IF EXISTS Property_Area
# 2022-10-09 00:07:47,327 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-10-09 00:07:47,336 INFO sqlalchemy.engine.Engine COMMIT
# 2022-10-09 00:07:47,338 INFO sqlalchemy.engine.Engine CREATE TABLE Property_Area(
#                Property_Area_ID  INT NOT NULL AUTO_INCREMENT,
#                Property_Area  VARCHAR(20),
#                PRIMARY KEY (Property_Area_ID)
#                )
# 2022-10-09 00:07:47,339 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-10-09 00:07:47,370 INFO sqlalchemy.engine.Engine COMMIT
# Property_Area
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,374 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,375 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:47,379 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,386 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,387 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:47,390 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,404 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,405 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:47,407 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,415 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,416 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:47,420 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,426 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,428 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:47,429 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,435 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,435 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:47,438 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,443 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,444 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:47,449 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,454 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,454 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:47,457 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,463 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,464 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:47,467 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,472 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,474 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:47,476 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,481 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,481 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:47,485 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,491 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,492 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:47,495 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,500 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,500 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:47,503 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,510 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,513 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:47,515 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,521 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,522 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:47,524 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,528 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,529 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:47,531 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,534 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,535 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:47,537 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,541 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,541 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:47,544 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47,548 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:47
INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,436 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:48,438 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,443 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,444 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:48,445 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,450 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,452 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:48,454 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,459 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,460 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:48,463 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,466 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,467 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:48,468 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,472 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,472 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:48,474 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,478 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,479 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:48,480 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,484 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,486 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:48,488 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,491 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,492 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:48,495 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,499 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,499 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:48,501 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,504 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,505 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:48,507 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,510 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,511 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:48,513 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,517 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,519 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:48,521 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,524 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:48,525 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:48,527 INFO sqlalchemy.engine.Engine COMMIT
# ...
# 2022-10-09 00:07:50,671 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,675 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,677 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:50,679 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,683 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,684 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:50,686 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,690 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,694 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,696 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,700 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,701 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,703 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,708 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,711 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,712 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,716 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,717 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,719 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,724 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,725 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,727 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,732 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,734 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,736 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,741 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,742 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:50,744 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,749 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,750 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,752 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,756 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,757 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:50,760 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,764 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,765 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:50,767 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,770 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,771 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:50,773 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,778 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,779 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:50,781 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,785 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,786 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:50,788 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,792 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,794 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:50,796 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,800 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,800 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:50,801 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,805 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,806 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:50,808 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,812 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,812 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,815 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,818 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,819 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,820 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,824 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,825 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:50,827 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,831 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,832 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:50,833 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,837 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,838 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:50,839 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,844 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,845 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:50,847 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,851 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,851 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,853 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,856 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,856 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:50,860 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,864 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,865 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,866 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,871 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,871 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:50,873 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,878 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,878 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:50,881 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,884 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,885 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:50,886 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,890 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,891 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,893 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,897 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,898 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,899 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,903 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,904 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,906 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,910 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,911 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,914 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,917 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,918 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:50,919 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,922 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,922 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:50,924 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,927 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,928 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:50,930 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,934 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,935 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:50,937 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,942 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,943 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,945 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,950 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,951 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:50,953 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,956 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,957 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:50,959 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,963 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,963 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:50,965 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,969 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,970 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:50,972 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,975 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,977 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:50,978 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,981 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,982 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,984 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,987 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,988 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:50,991 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,996 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:50,997 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:50,999 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:51,003 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:51,004 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:51,007 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:51,010 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:51,011 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:51,013 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:51,017 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:51,018 INFO sqlalchemy.engine.Engine [raw sql] ('Rural',)
# 2022-10-09 00:07:51,019 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:51,022 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:51,024 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:51,026 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:51,029 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:51,030 INFO sqlalchemy.engine.Engine [raw sql] ('Urban',)
# 2022-10-09 00:07:51,032 INFO sqlalchemy.engine.Engine COMMIT
# INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:51,034 INFO sqlalchemy.engine.Engine INSERT INTO Property_Area (Property_Area) VALUES (%s)
# 2022-10-09 00:07:51,035 INFO sqlalchemy.engine.Engine [raw sql] ('Semiurban',)
# 2022-10-09 00:07:51,038 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### Property_Area

# %% [markdown]
# ### Client

# %%
df_Client.head()
# Out:
#   Gender Married  Dependents     Education Self_Employed  Credit_History  \
# 1   Male     Yes           1      Graduate            No               1
# 2   Male     Yes           0      Graduate           Yes               1
# 3   Male     Yes           0  Not Graduate            No               1
# 4   Male      No           0      Graduate            No               1
# 5   Male     Yes           2      Graduate           Yes               1
#
#    ApplicantIncome  CoapplicantIncome
# 1             4583             1508.0
# 2             3000                0.0
# 3             2583             2358.0
# 4             6000                0.0
# 5             5417             4196.0

# %%
df_Client.dtypes
# Out:
# Gender                object
# Married               object
# Dependents             int32
# Education             object
# Self_Employed         object
# Credit_History         int32
# ApplicantIncome        int64
# CoapplicantIncome    float64
# dtype: object

# %% [raw]
# sql_query = '''CREATE TABLE Client(
#                Client_ID  INT NOT NULL AUTO_INCREMENT,
#                Gender  VARCHAR(10),
#                Married  VARCHAR(5),
#                Dependents  INT,
#                Education  VARCHAR(20),
#                Self_Employed  VARCHAR(5),
#                Credit_History  INT,
#                ApplicantIncome  INT,
#                CoapplicantIncome  FLOAT,
#                Property_Area_ID INT REFERENCES Property_Area(Property_Area_ID),
#                PRIMARY KEY (Client_ID),
#                FOREIGN KEY (Property_Area_ID) REFERENCES Property_Area(Property_Area_ID)
#                )'''

# %% [raw]
# # création de la table "Client"
# sql_query = ''' DROP TABLE IF EXISTS Client'''
# conn.execute(sql_query)
#
# sql_query = '''CREATE TABLE Client(
#                Client_ID  INT NOT NULL AUTO_INCREMENT,
#                Gender  VARCHAR(10),
#                Married  VARCHAR(5),
#                Dependents  INT,
#                Education  VARCHAR(20),
#                Self_Employed  VARCHAR(5),
#                Credit_History  INT,
#                ApplicantIncome  INT,
#                CoapplicantIncome  FLOAT,
#                Property_Area_ID INT,
#                PRIMARY KEY (Client_ID)
#                )'''
# #Property_Area_ID INT,
# #FOREIGN KEY (Property_Area_ID) REFERENCES Property_Area(Property_Area_ID)
# conn.execute(sql_query)
#
# #insertion des données"
# cols = ",".join([str(i) for i in df_Client.columns.tolist()]) # la liste des colonnes
# #print(cols)
# for i,row in df_Client.iterrows():
#     sql_query = "INSERT INTO Client (" +cols + ") VALUES (" + "%s,"*(len(row)-1) + "%s)"
#     #print(sql_query)
#     conn.execute(sql_query, tuple(row))
#
# sql_query = '''ALTER TABLE Client
#                 ADD CONSTRAINT fkClientPropertyArea FOREIGN KEY (Property_Area_ID) REFERENCES Property_Area(Property_Area_ID)'''
# conn.execute(sql_query)

# %%
# création de la table "Client" 
sql_query = ''' DROP TABLE IF EXISTS Client'''
conn.execute(sql_query)

sql_query = '''CREATE TABLE Client(
               Client_ID  INT NOT NULL AUTO_INCREMENT,
               Gender  VARCHAR(10),
               Married  VARCHAR(5),
               Dependents  INT,
               Education  VARCHAR(20),
               Self_Employed  VARCHAR(5),
               Credit_History  INT,
               ApplicantIncome  INT,
               CoapplicantIncome  FLOAT,
               Property_Area_ID INT,
               
               PRIMARY KEY (Client_ID),
               FOREIGN KEY (Property_Area_ID) REFERENCES Property_Area(Property_Area_ID)
               )'''

#Property_Area_ID INT,
#FOREIGN KEY (Property_Area_ID) REFERENCES Property_Area(Property_Area_ID)
conn.execute(sql_query)

#insertion des données"
cols = ",".join([str(i) for i in df_Client.columns.tolist()]) # la liste des colonnes
#print(cols)
for i,row in df_Client.iterrows():
    sql_query = "INSERT INTO Client (" +cols + ") VALUES (" + "%s,"*(len(row)-1) + "%s)"
    #print(sql_query)
    conn.execute(sql_query, tuple(row))
# Out:
# 2022-10-09 00:07:56,906 INFO sqlalchemy.engine.Engine  DROP TABLE IF EXISTS Client
# 2022-10-09 00:07:56,907 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-10-09 00:07:56,911 INFO sqlalchemy.engine.Engine COMMIT
# 2022-10-09 00:07
INFO sqlalchemy.engine.Engine COMMIT
# 2022-10-09 00:08:00,319 INFO sqlalchemy.engine.Engine INSERT INTO Client (Gender,Married,Dependents,Education,Self_Employed,Credit_History,ApplicantIncome,CoapplicantIncome) VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
# 2022-10-09 00:08:00,320 INFO sqlalchemy.engine.Engine [raw sql] ('Female', 'No', 0, 'Graduate', 'Yes', 0, 4583, 0.0)
# 2022-10-09 00:08:00,322 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### Méthode 2: insertion des données avec Pandas """Loan"""

# %%
df_Loan.head()
# Out:
#     Loan_ID  LoanAmount  Loan_Amount_Term Loan_Status
# 1  LP001003       128.0             360.0           N
# 2  LP001005        66.0             360.0           Y
# 3  LP001006       120.0             360.0           Y
# 4  LP001008       141.0             360.0           Y
# 5  LP001011       267.0             360.0           Y

# %%
df_Loan.to_sql(con=conn, name='loan', if_exists='replace', index=False) #Le nom de la table doit être en minuscule

with conn.connect() as con:
    con.execute('ALTER TABLE Loan_bdd.loan ADD PRIMARY KEY (Loan_ID(20));')
    con.execute('ALTER TABLE Loan_bdd.loan ADD Client_ID INT;')
    con.execute('ALTER TABLE Loan_bdd.loan ADD FOREIGN KEY (Client_ID) REFERENCES Client (Client_ID);')
# Out:
# 2022-10-09 00:08:00,377 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2022-10-09 00:08:00,379 INFO sqlalchemy.engine.Engine [generated in 0.00149s] {'table_schema': 'loan_bdd', 'table_name': 'loan'}
# 2022-10-09 00:08:00,383 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-10-09 00:08:00,384 INFO sqlalchemy.engine.Engine
# CREATE TABLE loan (
# 	`Loan_ID` TEXT,
# 	`LoanAmount` FLOAT(53),
# 	`Loan_Amount_Term` FLOAT(53),
# 	`Loan_Status` TEXT
# )
#
#
# 2022-10-09 00:08:00,386 INFO sqlalchemy.engine.Engine [no key 0.00134s] {}
# 2022-10-09 00:08:00,405 INFO sqlalchemy.engine.Engine COMMIT
# 2022-10-09 00:08:00,408 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-10-09 00:08:00,415 INFO sqlalchemy.engine.Engine INSERT INTO loan (`Loan_ID`, `LoanAmount`, `Loan_Amount_Term`, `Loan_Status`) VALUES (%(Loan_ID)s, %(LoanAmount)s, %(Loan_Amount_Term)s, %(Loan_Status)s)
# 2022-10-09 00:08:00,416 INFO sqlalchemy.engine.Engine [generated in 0.00559s] ({'Loan_ID': 'LP001003', 'LoanAmount': 128.0, 'Loan_Amount_Term': 360.0, 'Loan_Status': 'N'}, {'Loan_ID': 'LP001005', 'LoanAmount': 66.0, 'Loan_Amount_Term': 360.0, 'Loan_Status': 'Y'}, {'Loan_ID': 'LP001006', 'LoanAmount': 120.0, 'Loan_Amount_Term': 360.0, 'Loan_Status': 'Y'}, {'Loan_ID': 'LP001008', 'LoanAmount': 141.0, 'Loan_Amount_Term': 360.0, 'Loan_Status': 'Y'}, {'Loan_ID': 'LP001011', 'LoanAmount': 267.0, 'Loan_Amount_Term': 360.0, 'Loan_Status': 'Y'}, {'Loan_ID': 'LP001013', 'LoanAmount': 95.0, 'Loan_Amount_Term': 360.0, 'Loan_Status': 'Y'}, {'Loan_ID': 'LP001014', 'LoanAmount': 158.0, 'Loan_Amount_Term': 360.0, 'Loan_Status': 'N'}, {'Loan_ID': 'LP001018', 'LoanAmount': 168.0, 'Loan_Amount_Term': 360.0, 'Loan_Status': 'Y'}  ... displaying 10 of 517 total bound parameter sets ...  {'Loan_ID': 'LP002984', 'LoanAmount': 187.0, 'Loan_Amount_Term': 360.0, 'Loan_Status': 'Y'}, {'Loan_ID': 'LP002990', 'LoanAmount': 133.0, 'Loan_Amount_Term': 360.0, 'Loan_Status': 'N'})
# 2022-10-09 00:08:00,440 INFO sqlalchemy.engine.Engine COMMIT
# 2022-10-09 00:08:00,445 INFO sqlalchemy.engine.Engine ALTER TABLE Loan_bdd.loan ADD PRIMARY KEY (Loan_ID(20));
# 2022-10-09 00:08:00,446 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-10-09 00:08:00,537 INFO sqlalchemy.engine.Engine COMMIT
# 2022-10-09 00:08:00,538 INFO sqlalchemy.engine.Engine ALTER TABLE Loan_bdd.loan ADD Client_ID INT;
# 2022-10-09 00:08:00,539 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-10-09 00:08:00,554 INFO sqlalchemy.engine.Engine COMMIT
# 2022-10-09 00:08:00,555 INFO sqlalchemy.engine.Engine ALTER TABLE Loan_bdd.loan ADD FOREIGN KEY (Client_ID) REFERENCES Client (Client_ID);
# 2022-10-09 00:08:00,555 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-10-09 00:08:00,639 INFO sqlalchemy.engine.Engine COMMIT

# %% [raw]
# ALTER TABLE table_name
# ADD CONSTRAINT constraint_name
# FOREIGN KEY (foreign_key_name,...)
# REFERENCES parent_table(column_name,...);

# %% [markdown]
# On sort le schéma du modèle physique de données sur mysql workbench:
# - Cliquer sur l'onglet Database
# - Riverse Engineer

# %% [markdown]
# # Convertion des variables categorielles en variables numériques

# %%
new_train.head(3)
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 1  LP001003   Male     Yes           1      Graduate            No
# 2  LP001005   Male     Yes           0      Graduate           Yes
# 3  LP001006   Male     Yes           0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 1               1         Rural           N
# 2               1         Urban           Y
# 3               1         Urban           Y

# %%
new_train['Married'] = new_train['Married'].map(dict(Yes=1, No=0))
test['Married'] = test['Married'].map(dict(Yes=1, No=0))

# %%
new_train['Self_Employed'] = new_train['Self_Employed'].map(dict(Yes=1, No=0))
test['Self_Employed'] = test['Self_Employed'].map(dict(Yes=1, No=0))

# %%
new_train['Education'].value_counts()
# Out:
# Graduate        410
# Not Graduate    107
# Name: Education, dtype: int64

# %%
new_train.head(2)
# Out:
#     Loan_ID Gender  Married  Dependents Education  Self_Employed  \
# 1  LP001003   Male        1           1  Graduate              0
# 2  LP001005   Male        1           0  Graduate              1
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 1               1         Rural           N
# 2               1         Urban           Y

# %%
to_numeric = {'Male': 0, 'Female': 1,
              'Graduate': 1, 'Not Graduate': 0,
              'Urban': 3, 'Semiurban': 2,'Rural': 1,
              'Y': 1, 'N': 0,
              '3+': 3}

# %%
# adding the new numeric values from the to_numeric variable to both datasets
new_train = new_train.applymap(lambda elem: to_numeric.get(elem) if elem in to_numeric else elem)
test = test.applymap(lambda elem: to_numeric.get(elem) if elem in to_numeric else elem)

# %%
new_train['Education'].value_counts()
# Out:
# 1    410
# 0    107
# Name: Education, dtype: int64

# %%
new_train['Education'].dtypes
# Out:
# dtype('int64')

# %%
obj = (new_train.dtypes == 'object')
print("Categorical variables:",len(list(obj[obj].index)))
# Out:
# Categorical variables: 1

# %%
new_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 517 entries, 1 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            517 non-null    object
#  1   Gender             517 non-null    int64
#  2   Married            517 non-null    int64
#  3   Dependents         517 non-null    int64
#  4   Education          517 non-null    int64
#  5   Self_Employed      517 non-null    int64
#  6   ApplicantIncome    517 non-null    int64
#  7   CoapplicantIncome  517 non-null    float64
#  8   LoanAmount         517 non-null    float64
#  9   Loan_Amount_Term   517 non-null    float64
#  10  Credit_History     517 non-null    int64
#  11  Property_Area      517 non-null    int64
#  12  Loan_Status        517 non-null    int64
# dtypes: float64(3), int64(9), object(1)
# memory usage: 56.5+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    float64
#  2   Married            367 non-null    int64
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    int64
#  5   Self_Employed      344 non-null    float64
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    int64
# dtypes: float64(5), int64(5), object(2)
# memory usage: 34.5+ KB

# %%
#test['Gender '] = test['Gender'].astype(int)

# %% [markdown]
# ### Vérification des outliers

# %% [markdown]
# ### Supression des colonnes non utilisées pour la prédiction

# %%
new_train.drop('Loan_ID', axis=1, inplace=True)
test.drop('Loan_ID',axis=1,inplace=True)

# %%
new_train.head(2)
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1       0        1           1          1              0             4583
# 2       0        1           0          1              1             3000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0               1
# 2                0.0        66.0             360.0               1
#
#    Property_Area  Loan_Status
# 1              1            0
# 2              3            1

# %%
test.head(2)
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0     0.0        1          0          1            0.0             5720
# 1     0.0        1          1          1            0.0             3076
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0       110.0             360.0             1.0
# 1               1500       126.0             360.0             1.0
#
#    Property_Area
# 0              3
# 1              3

# %% [markdown]
# # DataViz

# %%
#Normalize peut être défini sur True pour imprimer les proportions au lieu du nombre
train['Loan_Status'].value_counts(normalize=True)
# Out:
# Y    0.694391
# N    0.305609
# Name: Loan_Status, dtype: float64

# %%
plt.pie(train['Loan_Status'].value_counts(), 
        labels=train['Loan_Status'].value_counts().index, 
        autopct='%1.1f%%',  
        startangle=90,
        textprops={'size': 'x-large'});
plt.legend(title = "Loan_Status :", loc ="center right", bbox_to_anchor =(1.4, 0.7));

# %%
train['Loan_Status'].value_counts().plot.bar();
plt.legend()

# %%
sns.countplot(train['Gender']).set_title('Sexe');

# %%
sns.countplot(train['Married']).set_title('Marrié ?');

# %%
sns.countplot(train['Education']).set_title('Diplômé ?');

# %% [markdown]
# ### Variables indépendantes Catégorielles

# %%
plt.figure(figsize = (10, 20)) 
plt.subplot(231) 
train['Gender'].value_counts(normalize=True).plot.bar(figsize=(20,10), title= 'Gender', color=['mediumvioletred', 'steelblue']) 
plt.subplot(232) 
train['Married'].value_counts(normalize=True).plot.bar(title= 'Married', color=['mediumvioletred', 'steelblue']) 
plt.subplot(233) 
train['Education'].value_counts(normalize=True).plot.bar(title= 'Education', color=['mediumvioletred', 'steelblue']) 
plt.subplot(234) 
train['Self_Employed'].value_counts(normalize=True).plot.bar(title= 'Self_Employed', color=['mediumvioletred', 'steelblue']) 
plt.subplot(235) 
train['Credit_History'].value_counts(normalize=True).plot.bar(title= 'Credit_History', color=['mediumvioletred', 'steelblue']) 
plt.tight_layout()
plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.2)
plt.show()

# %% [markdown]
# ### On peut déduire des diagrammes à barres ci-dessus que :
# - 80% des candidats dans l'ensemble de données sont des hommes.
# - Environ 65% des candidats de l'ensemble de données sont mariés.
# - Environ 80% des candidats sont diplômés.
# - Environ 15 % des candidats de l'ensemble de données sont des travailleurs indépendants.
# - Environ 85 % des demandeurs ont remboursé leurs dettes.

# %% [markdown]
# ### Variables indépendantes Ordinales

# %%
plt.figure(1) 
plt.subplot(121) 
train['Dependents'].value_counts(normalize=True).plot.bar(figsize=(24,6),title='Dependents', color=['mediumvioletred', 'palevioletred', 'steelblue', 'darkcyan']) 
plt.subplot(122) 
train['Property_Area'].value_counts(normalize=True).plot.bar(title= 'Property_Area', color=['mediumvioletred', 'palevioletred', 'steelblue'] ) 
plt.show()

# %% [markdown]
# - La plupart des demandeurs n'ont pas de personnes à charge.
# - La plupart des candidats sont issus de zones semi-urbaines.

# %%
train['Dependents'].value_counts()
# Out:
# 0    301
# 2     90
# 1     84
# 3     42
# Name: Dependents, dtype: int64

# %%
train['Dependents'].value_counts().index
# Out:
# Int64Index([0, 2, 1, 3], dtype='int64')

# %%
fig = plt.figure(figsize =(10, 7));
plt.pie(train['Dependents'].value_counts(), 
        labels=train['Dependents'].value_counts().index, 
        autopct='%1.1f%%',  
        startangle=90,
        textprops={'size': 'x-large'});
plt.legend(title = "Personnes à charge :", loc ="center right", bbox_to_anchor =(1.3, 0.7));

# %%
sns.countplot(train['Self_Employed']).set_title('Travailleur indépendant ?');

# %%
sns.countplot(train['Credit_History']).set_title('Crédit historique ?');

# %%
sns.catplot(x="Gender", y="Married",
            hue="Loan_Status", 
            kind="bar", 
            data=new_train);

# %%
sns.boxplot(x=train['LoanAmount']).set_title('Montant du prêt (en milliers)');

# %% [markdown]
# ## Suppression des valeurs aberrantes (Outliers)

# %% [markdown]
# - It can be seen that having outliers often has a significant effect on the mean and standard deviation
#   and hence affecting the distribution. We must take steps to remove outliers from our data sets.
# - Due to these outliers bulk of the data in the loan amount is at the left and the right tail is longer.
#   This is called right skewness.
# - One way to remove the skewness is by doing the log transformation.
#   As we take the log transformation, it does not affect the smaller values much but reduces the larger values.
#   So, we get a distribution similar to the normal distribution.

# %%
train['LoanAmount'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
train['LoanAmount'] = np.log(train['LoanAmount'])

# %%
train['LoanAmount'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=train['LoanAmount']).set_title('Montant du prêt (en milliers)');

# %%
test['LoanAmount'] = np.log(test['LoanAmount'])

# %%
test['LoanAmount'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=test['LoanAmount']).set_title('Montant du prêt (en milliers)');

# %% [markdown]
# - Maintenant, la distribution semble beaucoup plus proche de la normale et l'effet des valeurs extrêmes a été considérablement atténué.

# %% [markdown]
# # Partie 2 : Corrélations
#
# - Analyse de corrélation des variables
# - vérifier la multicolinéarité avec un heatmap (voir comment les variables indépendantes peuvent être corrélées)
# - Définir les variables significatives
# - transformer les variables continues

# %%
#Matrice de corrélation

corr_df = new_train.corr().abs()

upp_mat = np.triu(new_train.corr())

plt.figure(figsize=(20, 15))
sns.heatmap(corr_df, annot=True, mask=upp_mat)
#plt.savefig("Matrice de corrélation.png")
plt.show()

# %% [markdown]
# We can clearly see that Credit_History has the highest correlation with Loan_Status (a positive correlation of 0.54).
# Therefore our target value is highly dependant on this column.

# %% [markdown]
# ### Multi Colinéarité

# %% [markdown]
# * Vérifier la Multicolinéarité des features
#
# https://datascience.eu/fr/apprentissage-automatique/multicollinearite-2/
#
# https://datascience.eu/fr/mathematiques-et-statistiques/multicollinearite/

# %% [raw]
# def Multicollinear_Features():
#     corr = train.corr().abs()
#     features = []
#     correlations = []
#     for idx, correlation in corr['price'].T.iteritems():
#         if correlation >= .3 and idx != 'price':
#             features.append(idx)
#             correlations.append(correlation)
#     corr_price_df = pd.DataFrame({'Correlations':correlations, 'Features': features})
#     corr_price_df.sort_values(by='Correlations',ascending=False,inplace=True)
#     corr_price_df.reset_index(drop=True,inplace=True)
#
#     Multicollinear_Features = []
#     for feature in corr:
#         for idx, correlation in corr[feature].T.iteritems():
#             if correlation >= .8 and idx != feature and corr['price'].loc[feature] >= corr['price'].loc[idx]:
#                 Multicollinear_Features.append({'Correlations':correlation,'Features':feature,'idx': idx})
#     if len(Multicollinear_Features) > 0:
#         MC_df = pd.DataFrame(Multicollinear_Features)
#     else:
#         MC_df = pd.DataFrame(columns=['Correlations', 'Features','idx'])
#     MC_df.sort_values(by='Correlations',ascending=False,inplace=True)
#     MC_df.reset_index(drop=True,inplace=True)
#     print('Multicollinear Features')
#     display(MC_df)
#
#     print('Correlations with Target')
#     corr_price_df = corr_price_df.loc[~corr_price_df['Features'].isin(MC_df['idx'].to_list())]
#     display(corr_price_df)
#     return corr_price_df,MC_df

# %% [raw]
# corr_price_df, MC_df = Multicollinear_Features()

# %% [markdown]
# * Quels sont les meilleures variables , les plus significatives ?
#
# utiliser stepwise_selection pour choisir les meilleurs features
#
# https://towardsdatascience.com/feature-selection-techniques-in-regression-model-26878fe0e24e
#
# https://en.wikipedia.org/wiki/Stepwise_regression
#
# https://towardsdatascience.com/stepwise-regression-tutorial-in-python-ebf7c782c922
#
# https://bookdown.org/max/FES/greedy-stepwise-selection.html

# %% [raw]
# #Nouveau df avec les features qu'on garde
#
# values = []
# cols = []
# for col, value in df.iteritems():
#     if (col in corr_price_df['Features'].to_list()):
#         values.append(df[col])
#         cols.append(col)
# df1 = pd.concat(values,axis=1)
# df1

# %% [raw]
# df1 = df[['price'] + df1.columns.tolist()]
# df1

# %% [markdown]
# # Sauvegarde du nouveau df propre

# %%
new_train.to_csv('train_propre.csv', index=False)

# %%
test.to_csv('test_propre.csv', index=False)
